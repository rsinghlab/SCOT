# %% [markdown]
# ## Unbalanced Gromov-Wasserstein for SNARE-seq example
#
# To simulate imbalance between cell types, we subsample the ATAC dataset and try to align to the full RNA dataset.

# %%
import sys
sys.path.insert(1, '../src/')
import utils as ut
import evals as evals
import scot2 as sc
from sklearn.cluster import SpectralClustering
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np

# %%
X=np.load("../data/scatac_feat.npy") 
y=np.load("../data/scrna_feat.npy")
print("Dimensions of input datasets are: ", "X= ", X.shape, " y= ", y.shape)
# Out:
# Dimensions of input datasets are:  X=  (1047, 19)  y=  (1047, 10)

# %%
X=ut.unit_normalize(X)
y=ut.unit_normalize(y)

# %% [markdown]
# Can't find the cell-type information for now, so assign cluster labels based on spectral clustering. This seems relatively clean...

# %%
pca=PCA(n_components=2)
y_pca = pca.fit_transform(y)

clustering = SpectralClustering(n_clusters = 4, assign_labels = "discretize", random_state = 0).fit(y_pca)
plt.scatter(y_pca[:, 0], y_pca[:, 1], s = 4, c = clustering.labels_)

# %% [markdown]
# Now subsample the ATAC data according to class proportions `props`

# %%
props = [0.5, 1, 0.75, 0.5]
index = np.concatenate([np.where(clustering.labels_ == i)[0][0:int((clustering.labels_ == i).sum() * props[i])] for i in range(len(props))])
X_subsamp = X[index, :]

X_subsamp_pca = pca.fit_transform(X_subsamp)
plt.scatter(X_subsamp_pca[:, 0], X_subsamp_pca[:, 1], s = 4, c = clustering.labels_[index])

# %%
# initialize SCOT object
scot=sc.SCOT(X_subsamp, y)

# %% [markdown]
# Align using balanced and unbalanced Gromov-Wasserstein

# %%
# call the unbalanced alignment 
X_new_bal, y_new_bal = scot.align(k=50, e=0.0005,  normalize=False)
# Out:
# It.  |Err
# -------------------
#     0|2.512857e-03|
#    10|9.632699e-04|
#    20|2.201648e-04|
#    30|9.146903e-05|
#    40|5.387046e-05|
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f2a3e27147fa> in <module>
#       1 # call the unbalanced alignment
# ----> 2 X_new_bal, y_new_bal = scot.align(k=50, e=0.0005,  normalize=False)
#
# ~/Documents/ManifoldAlignment/SCOT-master/src/scot2.py in align(self, k, e, balanced, rho, verbose, normalize, norm, XontoY)
#     196         self.build_kNN(k)
#     197         self.compute_graphDistances()
# --> 198         self.find_correspondences(e=e, balanced=balanced,  rho=rho, verbose=verbose)
#     199         X_aligned, y_aligned = self.barycentric_projection(XontoY)
#     200         return X_aligned, y_aligned
#
# ~/Documents/ManifoldAlignment/SCOT-master/src/scot2.py in find_correspondences(self, e, balanced, rho, verbose)
#     162         self.flag = True
#     163         if balanced:
# --> 164             self.coupling, log = ot.gromov.entropic_gromov_wasserstein(self.Cx, self.Cy, self.p, self.q, 'square_loss', epsilon=e, log=True, verbose=verbose)
#     165             self.gwdist= log['gw_dist']
#     166
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/ot/gromov.py in entropic_gromov_wasserstein(C1, C2, p, q, loss_fun, epsilon, max_iter, tol, verbose, log)
#     655         tens = gwggrad(constC, hC1, hC2, T)
#     656
# --> 657         T = sinkhorn(p, q, tens, epsilon)
#     658
#     659         if cpt % 10 == 0:
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/ot/bregman.py in sinkhorn(a, b, M, reg, method, numItermax, stopThr, verbose, log, **kwargs)
#     112         return sinkhorn_knopp(a, b, M, reg, numItermax=numItermax,
#     113                               stopThr=stopThr, verbose=verbose, log=log,
# --> 114                               **kwargs)
#     115     elif method.lower() == 'greenkhorn':
#     116         return greenkhorn(a, b, M, reg, numItermax=numItermax,
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/ot/bregman.py in sinkhorn_knopp(a, b, M, reg, numItermax, stopThr, verbose, log, **kwargs)
#     362         KtransposeU = np.dot(K.T, u)
#     363         v = np.divide(b, KtransposeU)
# --> 364         u = 1. / np.dot(Kp, v)
#     365
#     366         if (np.any(KtransposeU == 0)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
X_new_unbal, y_new_unbal = scot.align(k=50, e=1e-3, rho = 0.0005, normalize=False, balanced = False)
# Out:
# It.  |Err
# -------------------
#     0|1.104449e-03|
# /home/rebecca/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/ot/unbalanced.py:394: RuntimeWarning: divide by zero encountered in true_divide
#   u = (a / Kv) ** fi
# /home/rebecca/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/ot/unbalanced.py:403: UserWarning: Numerical errors at iteration 0
#   warnings.warn('Numerical errors at iteration %s' % i)
#    10|0.000000e+00|
# ../src/scot2.py:183: RuntimeWarning: invalid value encountered in true_divide
#   self.coupling=self.coupling / np.sum(self.coupling)

# %% [markdown]
# We have aligned the ATAC dataset (subsampled) onto the RNA dataset (full).

# %%
pca=PCA(n_components=2)
Xy_pca_bal=pca.fit_transform(np.concatenate((X_new_bal, y_new), axis=0))
X_pca_bal=Xy_pca_bal[0:X_new_bal.shape[0],]
y_pca_bal=Xy_pca_bal[X_new_bal.shape[0]:,]
Xy_pca_unbal=pca.fit_transform(np.concatenate((X_new_unbal, y_new), axis=0))
X_pca_unbal=Xy_pca_unbal[0:X_new_unbal.shape[0],]
y_pca_unbal=Xy_pca_unbal[X_new_unbal.shape[0]:,]

### Read in cell type information:
# Xlabels=np.genfromtxt("data/SNAREseq_typesChromatin.txt")
# ylabels=np.genfromtxt("data/SNAREseq_typesExpression.txt")

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15, 5))
ax1.scatter(y_pca_bal[:,0], y_pca_bal[:,1], s=15, label="Gene Expression", alpha = 0.5, c = clustering.labels_, marker = "+")
ax1.set_title("Expression")

ax2.scatter(X_pca_unbal[:,0], X_pca_unbal[:,1], s=15, label="Chromatin Accessibility", alpha = 0.5, c = clustering.labels_[index], marker = "^")
ax2.set_title("ATAC, unbalanced")

ax3.scatter(X_pca_bal[:,0], X_pca_bal[:,1], s=15, label="Chromatin Accessibility", alpha = 0.5, c = clustering.labels_[index], marker = "^")
ax3.set_title("ATAC, balanced")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-0ea07d3cb613> in <module>
#       3 X_pca_bal=Xy_pca_bal[0:X_new_bal.shape[0],]
#       4 y_pca_bal=Xy_pca_bal[X_new_bal.shape[0]:,]
# ----> 5 Xy_pca_unbal=pca.fit_transform(np.concatenate((X_new_unbal, y_new), axis=0))
#       6 X_pca_unbal=Xy_pca_unbal[0:X_new_unbal.shape[0],]
#       7 y_pca_unbal=Xy_pca_unbal[X_new_unbal.shape[0]:,]
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     374         C-ordered array, use 'np.ascontiguousarray'.
#     375         """
# --> 376         U, S, V = self._fit(X)
#     377         U = U[:, :self.n_components_]
#     378
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     396
#     397         X = self._validate_data(X, dtype=[np.float64, np.float32],
# --> 398                                 ensure_2d=True, copy=self.copy)
#     399
#     400         # Handle n_components==None
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# ~/Documents/ManifoldAlignment/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# For a (row-normalised) coupling $P$, we can compute the expected class membership error:
# $$\mathbf{E}_{(x, y) \sim P} \mathbf{1}\{ \mathrm{class}(x) \ne \mathrm{class}(y) \}$$

# %%
P_unbal = (gamma_unbal.T/gamma_unbal.sum(1)).T
mean_err_unbal = (P_unbal*(clustering.labels_[index, None] != clustering.labels_[None, :])).sum(1).mean()
P_bal = (gamma_bal.T/gamma_bal.sum(1)).T
mean_err_bal = (P_bal*(clustering.labels_[index, None] != clustering.labels_[None, :])).sum(1).mean()

# %%
print("unbalanced: %f, balanced: %f" % (mean_err_unbal, mean_err_bal))
# Out:
# unbalanced: 0.138904, balanced: 0.254218
